# %%
import utilities as utils
import configs_py3 as configs

# %%
def main():
    img_path = f"{configs.ROOT}/VQA/Images/mscoco/val2014/COCO_val2014_000000000042.jpg"
    annotated_image = utils.display_objects_in_image(img_path)
    display(annotated_image)
    objects_in_image = utils.get_objects_in_image(img_path)
    print(objects_in_image)

# %%
if __name__ == "__main__":
    main()
# Out:
# <PIL.Image.Image image mode=RGB size=640x478>
# {'dog': 0.9825553894042969}
